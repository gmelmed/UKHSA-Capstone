# %% [markdown]
# ## Converting PDFs into Markdown format

# %%
# %pip install docling
# %pip install pymupdf4llm
# %pip install ocrmypdf
# %pip install markitdown
# %pip install pytesseract
# Out:
# Collecting docling
#   Downloading docling-2.26.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (2024.8.30)
# Collecting docling-core<3.0.0,>=2.19.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading docling_core-2.23.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting docling-ibm-models<4.0.0,>=3.4.0 (from docling)
#   Using cached docling_ibm_models-3.4.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docling-parse<4.0.0,>=3.3.0 (from docling)
#   Downloading docling_parse-3.4.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (9.5 kB)
# Collecting easyocr<2.0,>=1.7 (from docling)
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting huggingface_hub<1,>=0.23 (from docling)
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (5.2.1)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Using cached marko-2.1.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (2.2.2)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (2.8.2)
# Collecting pydantic-settings<3.0.0,>=2.3.0 (from docling)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pypdfium2<5.0.0,>=4.30.0 (from docling)
#   Using cached pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Using cached python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Using cached python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (2.32.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading rtree-1.4.0-py3-none-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (1.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling) (4.66.5)
# Collecting typer<0.13.0,>=0.12.5 (from docling)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.5)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (4.23.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached latex2mathml-3.77.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (6.0.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (0.9.0)
# Collecting typing-extensions<5.0.0,>=4.12.2 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.24.4 in /opt/anaconda3/lib/python3.12/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (1.26.4)
# Collecting opencv-python-headless<5.0.0.0,>=4.6.0.66 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Collecting safetensors<1,>=0.4.3 (from safetensors[torch]<1,>=0.4.3->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting torch<3.0.0,>=2.2.2 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting torchvision<1,>=0 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading torchvision-0.21.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: scikit-image in /opt/anaconda3/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling) (0.24.0)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling)
#   Downloading python_bidi-0.6.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting Shapely (from easyocr<2.0,>=1.7->docling)
#   Downloading shapely-2.0.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-macosx_10_13_universal2.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling)
#   Using cached ninja-1.11.1.3-py3-none-macosx_10_9_universal2.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub<1,>=0.23->docling) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub<1,>=0.23->docling) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub<1,>=0.23->docling) (24.1)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl<4.0.0,>=3.1.5->docling) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (0.21.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Using cached XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling) (2.2.3)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.13.0,>=0.12.5->docling) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<0.13.0,>=0.12.5->docling)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.13.0,>=0.12.5->docling) (13.7.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4.0.0,>=3.4.0->docling) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (0.10.6)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (2.15.1)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (75.1.0)
# Collecting sympy==1.13.1 (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.19.0->docling) (2024.9.11)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: imageio>=2.33 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (2.1.3)
# Collecting multiprocess>=0.70.15 (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading multiprocess-0.70.17-py312-none-any.whl.metadata (7.2 kB)
# Collecting dill>=0.3.9 (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading docling-2.26.0-py3-none-any.whl (146 kB)
# Downloading docling_core-2.23.0-py3-none-any.whl (115 kB)
# Using cached docling_ibm_models-3.4.1-py3-none-any.whl (80 kB)
# Downloading docling_parse-3.4.0-cp312-cp312-macosx_14_0_arm64.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 13.6 MB/s eta 0:00:00a 0:00:01
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Using cached marko-2.1.2-py3-none-any.whl (42 kB)
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Using cached pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl (2.8 MB)
# Using cached python_docx-1.1.2-py3-none-any.whl (244 kB)
# Using cached python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading rtree-1.4.0-py3-none-macosx_11_0_arm64.whl (439 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Using cached latex2mathml-3.77.0-py3-none-any.whl (73 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Using cached semchunk-2.2.2-py3-none-any.whl (10 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading torch-2.6.0-cp312-none-macosx_11_0_arm64.whl (66.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 16.3 MB/s eta 0:00:00a 0:00:01
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Downloading torchvision-0.21.0-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.0 MB/s eta 0:00:00
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
# Using cached ninja-1.11.1.3-py3-none-macosx_10_9_universal2.whl (279 kB)
# Downloading pyclipper-1.3.0.post6-cp312-cp312-macosx_10_13_universal2.whl (270 kB)
# Downloading python_bidi-0.6.6-cp312-cp312-macosx_11_0_arm64.whl (262 kB)
# Downloading shapely-2.0.7-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 16.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py312-none-any.whl (147 kB)
# Using cached mpire-2.10.2-py3-none-any.whl (272 kB)
# Using cached dill-0.3.9-py3-none-any.whl (119 kB)
# Installing collected packages: python-bidi, pyclipper, filetype, XlsxWriter, typing-extensions, sympy, shellingham, Shapely, safetensors, rtree, pypdfium2, opencv-python-headless, ninja, mpire, marko, latex2mathml, jsonref, jsonlines, dill, torch, python-pptx, python-docx, multiprocess, huggingface_hub, typer, torchvision, tokenizers, transformers, semchunk, pydantic-settings, easyocr, docling-core, docling-parse, docling-ibm-models, docling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
#   Attempting uninstall: rtree
#     Found existing installation: Rtree 1.0.1
#     Uninstalling Rtree-1.0.1:
#       Successfully uninstalled Rtree-1.0.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
# Successfully installed Shapely-2.0.7 XlsxWriter-3.2.2 dill-0.3.9 docling-2.26.0 docling-core-2.23.0 docling-ibm-models-3.4.1 docling-parse-3.4.0 easyocr-1.7.2 filetype-1.2.0 huggingface_hub-0.29.3 jsonlines-3.1.0 jsonref-1.1.0 latex2mathml-3.77.0 marko-2.1.2 mpire-2.10.2 multiprocess-0.70.17 ninja-1.11.1.3 opencv-python-headless-4.11.0.86 pyclipper-1.3.0.post6 pydantic-settings-2.8.1 pypdfium2-4.30.1 python-bidi-0.6.6 python-docx-1.1.2 python-pptx-1.0.2 rtree-1.4.0 safetensors-0.5.3 semchunk-2.2.2 shellingham-1.5.4 sympy-1.13.1 tokenizers-0.21.1 torch-2.6.0 torchvision-0.21.0 transformers-4.49.0 typer-0.12.5 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting pymupdf4llm
#   Using cached pymupdf4llm-0.0.17-py3-none-any.whl.metadata (4.1 kB)
# Collecting pymupdf>=1.24.10 (from pymupdf4llm)
#   Downloading pymupdf-1.25.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Using cached pymupdf4llm-0.0.17-py3-none-any.whl (26 kB)
# Downloading pymupdf-1.25.4-cp39-abi3-macosx_11_0_arm64.whl (18.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 17.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pymupdf, pymupdf4llm
# Successfully installed pymupdf-1.25.4 pymupdf4llm-0.0.17
# Note: you may need to restart the kernel to use updated packages.
# Collecting ocrmypdf
#   Using cached ocrmypdf-16.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting deprecation>=2.1.0 (from ocrmypdf)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting img2pdf>=0.5 (from ocrmypdf)
#   Using cached img2pdf-0.6.0.tar.gz (106 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/lib/python3.12/site-packages (from ocrmypdf) (24.1)
# Collecting pdfminer-six>=20220319 (from ocrmypdf)
#   Using cached pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Collecting pi-heif (from ocrmypdf)
#   Downloading pi_heif-0.22.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.5 kB)
# Collecting pikepdf>=8.10.1 (from ocrmypdf)
#   Downloading pikepdf-9.5.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: pillow>=10.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from ocrmypdf) (10.4.0)
# Requirement already satisfied: pluggy>=1 in /opt/anaconda3/lib/python3.12/site-packages (from ocrmypdf) (1.0.0)
# Requirement already satisfied: rich>=13 in /opt/anaconda3/lib/python3.12/site-packages (from ocrmypdf) (13.7.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pdfminer-six>=20220319->ocrmypdf) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pdfminer-six>=20220319->ocrmypdf) (43.0.0)
# Collecting Deprecated (from pikepdf>=8.10.1->ocrmypdf)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: lxml>=4.8 in /opt/anaconda3/lib/python3.12/site-packages (from pikepdf>=8.10.1->ocrmypdf) (5.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13->ocrmypdf) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13->ocrmypdf) (2.15.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf) (0.1.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.12/site-packages (from Deprecated->pikepdf>=8.10.1->ocrmypdf) (1.14.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.21)
# Using cached ocrmypdf-16.10.0-py3-none-any.whl (162 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
# Downloading pikepdf-9.5.2-cp312-cp312-macosx_14_0_arm64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Downloading pi_heif-0.22.0-cp312-cp312-macosx_14_0_arm64.whl (559 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.8/559.8 kB 13.1 MB/s eta 0:00:00
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: img2pdf
#   Building wheel for img2pdf (setup.py) ... done
#   Created wheel for img2pdf: filename=img2pdf-0.6.0-py3-none-any.whl size=51004 sha256=133949f5f70b83bea4d44c0122e1a4619c483cb11300a3106e40d7059cc8981c
#   Stored in directory: /Users/gabrielmelmed/Library/Caches/pip/wheels/ab/d8/41/6185e82645a6c7c52c2fe5a1287eb7c85dba2e9ac5e6ce78e2
# Successfully built img2pdf
# Installing collected packages: pi-heif, deprecation, Deprecated, pikepdf, pdfminer-six, img2pdf, ocrmypdf
# Successfully installed Deprecated-1.2.18 deprecation-2.1.0 img2pdf-0.6.0 ocrmypdf-16.10.0 pdfminer-six-20240706 pi-heif-0.22.0 pikepdf-9.5.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting markitdown
#   Downloading markitdown-0.0.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting azure-ai-documentintelligence (from markitdown)
#   Downloading azure_ai_documentintelligence-1.0.1-py3-none-any.whl.metadata (53 kB)
# Collecting azure-identity (from markitdown)
#   Downloading azure_identity-1.21.0-py3-none-any.whl.metadata (81 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (4.12.3)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (3.3.2)
# Collecting mammoth (from markitdown)
#   Using cached mammoth-1.9.0-py2.py3-none-any.whl.metadata (24 kB)
# Collecting markdownify (from markitdown)
#   Using cached markdownify-1.1.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (1.26.4)
# Collecting olefile (from markitdown)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (1.66.3)
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (3.1.5)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (2.2.2)
# Collecting pathvalidate (from markitdown)
#   Using cached pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pdfminer-six in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (20240706)
# Collecting puremagic (from markitdown)
#   Using cached puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Collecting pydub (from markitdown)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python-pptx in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (1.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from markitdown) (2.32.3)
# Collecting speechrecognition (from markitdown)
#   Using cached SpeechRecognition-3.14.1-py3-none-any.whl.metadata (31 kB)
# Collecting xlrd (from markitdown)
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting youtube-transcript-api (from markitdown)
#   Downloading youtube_transcript_api-1.0.1-py3-none-any.whl.metadata (22 kB)
# Collecting isodate>=0.6.1 (from azure-ai-documentintelligence->markitdown)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-documentintelligence->markitdown)
#   Using cached azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from azure-ai-documentintelligence->markitdown) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from azure-identity->markitdown) (43.0.0)
# Collecting msal>=1.30.0 (from azure-identity->markitdown)
#   Downloading msal-1.32.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->markitdown)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->markitdown) (2.5)
# Collecting cobble<0.2,>=0.1.3 (from mammoth->markitdown)
#   Using cached cobble-0.1.4-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six<2,>=1.15 in /opt/anaconda3/lib/python3.12/site-packages (from markdownify->markitdown) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.12/site-packages (from openai->markitdown) (4.66.5)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl->markitdown) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->markitdown) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->markitdown) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->markitdown) (2023.3)
# Requirement already satisfied: Pillow>=3.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from python-pptx->markitdown) (10.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from python-pptx->markitdown) (3.2.2)
# Requirement already satisfied: lxml>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-pptx->markitdown) (5.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->markitdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->markitdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->markitdown) (2024.8.30)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from youtube-transcript-api->markitdown) (0.7.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity->markitdown) (1.17.1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai->markitdown) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->markitdown) (0.14.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->markitdown) (2.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai->markitdown) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai->markitdown) (2.20.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->markitdown) (2.21)
# Downloading markitdown-0.0.2-py3-none-any.whl (21 kB)
# Downloading azure_ai_documentintelligence-1.0.1-py3-none-any.whl (106 kB)
# Downloading azure_identity-1.21.0-py3-none-any.whl (189 kB)
# Using cached mammoth-1.9.0-py2.py3-none-any.whl (52 kB)
# Using cached markdownify-1.1.0-py3-none-any.whl (13 kB)
# Using cached olefile-0.47-py2.py3-none-any.whl (114 kB)
# Using cached pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Using cached puremagic-1.28-py3-none-any.whl (43 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached SpeechRecognition-3.14.1-py3-none-any.whl (32.9 MB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading youtube_transcript_api-1.0.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.0 MB/s eta 0:00:00
# Using cached azure_core-1.32.0-py3-none-any.whl (198 kB)
# Using cached cobble-0.1.4-py3-none-any.whl (4.0 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.32.0-py3-none-any.whl (114 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Installing collected packages: pydub, puremagic, xlrd, speechrecognition, pathvalidate, olefile, isodate, cobble, youtube-transcript-api, markdownify, mammoth, azure-core, azure-ai-documentintelligence, msal, msal-extensions, azure-identity, markitdown
# Successfully installed azure-ai-documentintelligence-1.0.1 azure-core-1.32.0 azure-identity-1.21.0 cobble-0.1.4 isodate-0.7.2 mammoth-1.9.0 markdownify-1.1.0 markitdown-0.0.2 msal-1.32.0 msal-extensions-1.3.1 olefile-0.47 pathvalidate-3.2.3 puremagic-1.28 pydub-0.25.1 speechrecognition-3.14.1 xlrd-2.0.1 youtube-transcript-api-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting pytesseract
#   Using cached pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract) (10.4.0)
# Using cached pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytesseract
# Run in your terminal the following lines if this package doesn't work
# sudo apt-get update
# sudo apt-get install tesseract-ocr
# sudo apt-get update
# sudo apt-get install ghostscript
# Out:
# Requirement already satisfied: pytesseract in /opt/anaconda3/lib/python3.12/site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract) (10.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Loading packages
import os
from docling.document_converter import DocumentConverter
import pymupdf4llm
import ocrmypdf

# %%
# Sample of countries
sample_countries = [
    # 'Finland','Netherlands','Denmark','Norway','Bangladesh', 
    'Libya', 'Malta', 'Myanmar', 'Oman', 'Australia_2021-01-01'] # ["Chile","Ecuador"]

# Finding the PDFs related to the sample of countries
pdfs = []

# Folder with raw PDFs
folder_pdfs = "../data/1-naps-pdfs-raw"

for file in os.listdir(folder_pdfs):
    # Checking if any country name from sample_countries is in the file name
    if any(country in file for country in sample_countries):
        pdfs.append(file)
print(pdfs)
# Out:
# ['Myanmar_2017-07-01.pdf', 'Malta_2022-05-26.pdf', 'Libya_2018-12-28.pdf', 'Oman_2020-12-29.pdf', 'Australia_2021-01-01.pdf']

# %%
# Pre-processing the PDFs: OCR and conversion to text (TO DO IN TERMINAL. STILL DOESN'T WORK IN PYTHON)
# Example in Terminal: # ocrmypdf -l spa Chile_2022-03-09.pdf Chile_2022-03-09_clean.pdf

#for pdf in pdfs:
    # OCR
#    ocrmypdf.ocr(f"../data/1-naps-pdfs-raw/{pdf}", f"../data/2-naps-pdfs-clean/{pdf}")

# %%
# Function: Converter
converter = DocumentConverter()

# Folder to save Markdown files
folder_md = "../data/3-naps-md"

for pdf in pdfs:
    # Converting the PDF
    result = converter.convert(os.path.join(folder_pdfs, pdf))
    
    # Exporting the content into markdown format
    markdown_content = result.document.export_to_markdown()
    
    # Constructing the file name
    markdown_filename = os.path.splitext(pdf)[0] + '.md'
    
    # File path
    markdown_filepath = os.path.join(folder_md, markdown_filename)
    
    # Saving
    with open(markdown_filepath, 'w') as md_file:
        md_file.write(markdown_content)
